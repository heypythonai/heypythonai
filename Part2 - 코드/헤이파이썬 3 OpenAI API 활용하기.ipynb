# %% [markdown]
# # 3-3 챗GPT API 사용해 보기

# %%
# !pip install openai

# %%
import os
from getpass import getpass

os.environ['OPENAI_API_KEY'] = getpass()

# %%
from google.colab import userdata

userdata.get('OPENAI_API_KEY')

# %%
from openai import OpenAI
from google.colab import userdata
client = OpenAI(api_key=userdata.get('OPENAI_API_KEY'))

# %%
completion = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "당신은 헤이마트의 상담원입니다."},
        {"role": "user", "content": "안녕하세요!"}
    ]
)
completion.choices[0].message
# Out:
# ChatCompletionMessage(content='안녕하세요! 헤이마트에 오신 것을 환영합니다. 무엇을 도와드릴까요?', role='assistant', function_call=None, tool_calls=None)

# %%
completion = client.chat.completions.create(
    model="gpt-3.5-turbo-1106",
    messages=[
        {"role": "system", "content": "당신은 헤이마트의 상담원입니다."},
        {"role": "user", "content": "저녁으로 무엇을 먹을까요? 짧게 설명해주세요."}
    ],
    temperature=1.8,
    max_tokens=100,
    top_p=1,
    presence_penalty=0,
    frequency_penalty=0,
    n=2,
    stop=None
)

for choice in completion.choices:
    print(choice.index, choice.message.content)
# Out:
# 0 저녁으로 채식 요리인 시원한 그린 샐러드나 생선 스테이크와 채소를 곁들인 요푸라이요. 상쾌하고 건강한 선택입니다!
# 1 생선 요리를 먹을 것을 추천합니다. 생선은 건강에 좋은 비타민과 단백질이 풍부하며 가볍게 먹으면서 영양을 충분히 섭취할 수 있어 좋습니다. 또한 다양한 요리 방법으로 다채로
