# %% [markdown]
# #7-2 클래스및객체생성

# %%
class Goods:
  pass

# %%
cola = Goods()

# %%
class Goods:
  name = ''       # 상품 이름
  price = 0       # 상품 가격
  sale = 100      # 상품 할인
  make_date = ''  # 상품 등록일
  manager = ''    # 등록한 사람

cola = Goods()
jelly = Goods()

cola.price = 1500
jelly.price = 1000
print(cola.price)
print(jelly.price)
# Out:
# 1500
# 1000

# %%
cola = Goods()
jelly = Goods()
Goods.price = 500
print(cola.price)
print(jelly.price)
# Out:
# 500
# 500

# %%
cola = Goods()
jelly = Goods()
cola.price = 1000
Goods.price = 500
print(cola.price)
print(jelly.price)
# Out:
# 1000
# 500

# %%
class Goods:
  name = '' # 상품 이름
  rice = 0  # 상품 가격

  def make(self,name,price):
    self.name = name
    self.price = price

cola = Goods()
cola.make('콜라',1500)
print(cola.name)
print(cola.price)
# Out:
# 콜라
# 1500

# %%
class Goods:
  def __init__(self):
    print('생성자 실행')

cola = Goods()
# Out:
# 생성자 실행

# %%
class Goods:
  def __init__(self,name,price):
    print(name)
    print(price)

cola = Goods()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-426933548a51> in <cell line: 6>()
#       4     print(price)
#       5
# ----> 6 cola = Goods()
#
# TypeError: Goods.__init__() missing 2 required positional arguments: 'name' and 'price'

# %%
cola = Goods('콜라',1500)
# Out:
# 콜라
# 1500

# %%
class Goods:
  name = '상품명'
  price = 0

class Sale_goods(Goods):

  def make(self,name,price):
    self.name = name
    self.price = price

  def print_goods(self):
    print(self.name)
    print(self.price)

sale_cola = Sale_goods()
sale_cola.print_goods()
print('*'*20)
sale_cola.make('콜라',1500)
sale_cola.print_goods()
# Out:
# 상품명
# 0
# ********************
# 콜라
# 1500

# %%
class Goods:
  def __init__(self):
    print('Goods클래스 생성자')

class Sale_goods(Goods):
  pass

sale_cola = Sale_goods()
# Out:
# Goods클래스 생성자

# %%
class Goods:
  def __init__(self):
    print('Goods클래스 생성자')

class Sale_goods(Goods):
  def __init__(self):
    print('Sale_goods클래스 생성자')
  pass

sale_cola = Sale_goods()
# Out:
# Sale_goods클래스 생성자

# %%
class Goods:
  def __init__(self,name):
    self.name = name
    print(self.name)
    print('Goods 클래스 생성자')

class Sale_goods(Goods):
  def __init__(self,name):
    super().__init__(name)
    print('Sale_goods 클래스 생성자')
  pass

sale_cola = Sale_goods('콜라')
# Out:
# 콜라
# Goods 클래스 생성자
# Sale_goods 클래스 생성자
